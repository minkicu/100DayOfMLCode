# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# String variable

# %%
s='Hello World'
s1="Hello World"
s2="""I'm a student."""

print(s)
print(s1)
print(s2)

print(s[1],s[2],s[3])

print(s[1:5])
# Out:
# Hello World
# Hello World
# I'm a student.
# e l l
# ello

# %%
f=open('TH_DATA.csv',encoding='cp874')
for line in f:
    print(line)
f.close()
# Out:
# รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# Average Monthly Income Per Household: 1998 - 2015,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,บาท   Baht  ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ภาค และจังหวัด,,2541,2543,2545,2547,2549,2550,2552,2554,2556,2558,Region and province,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,(1998),(2000),(2002),(2004),(2006),(2007),(2009),(2011),(2013),(2015),,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
#  ทั่วราชอาณาจักร ,," 12,492 "," 12,150 "," 13,736 "," 14,963 "," 17,787 "," 18,660 "," 20,904 "," 23,236 "," 25,194 "," 26,915 ", Whole Kingdom ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ...

# %%
import random

a1=[1,2,3,4]
print(a1)

a2=['H','e','l','l','o',' ','W','o','r','l','d']
print(a2)

a3=list("Hello World")
print(a3)

a4='I am a cat.'.split()
print(a4)

a5=[x for x in range(5)]
print(a5)

a6=[random.randint(1,1000) for i in range(10)]
print(a6)
# Out:
# [1, 2, 3, 4]
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']
# ['I', 'am', 'a', 'cat.']
# [0, 1, 2, 3, 4]
# [909, 860, 950, 51, 184, 951, 480, 340, 159, 506]

# %%
for d in a6:
    print(d)
x=15
if x in a6:
    print(x,' In list')
else:
    print(x,' Out list')
# Out:
# 909
# 860
# 950
# 51
# 184
# 951
# 480
# 340
# 159
# 506
# 15  Out list

# %%
from collections import Counter

data=[random.randint(1,20) for i in range(100)]
print(data)
counts=Counter(data)
counts.most_common() #Count member in list
# Out:
# [1, 9, 14, 2, 8, 14, 9, 16, 3, 14, 19, 6, 15, 15, 18, 4, 16, 18, 1, 4, 4, 18, 1, 10, 18, 11, 8, 6, 16, 12, 9, 11, 10, 5, 9, 6, 15, 17, 2, 2, 5, 13, 8, 16, 7, 16, 11, 13, 4, 12, 9, 16, 5, 14, 17, 18, 4, 9, 16, 15, 14, 19, 18, 3, 5, 6, 20, 16, 6, 10, 16, 2, 10, 4, 12, 4, 3, 11, 13, 12, 19, 10, 13, 11, 16, 13, 15, 11, 16, 8, 19, 14, 6, 8, 15, 9, 20, 7, 6, 7]
# [(16, 11),
#  (9, 7),
#  (6, 7),
#  (4, 7),
#  (14, 6),
#  (15, 6),
#  (18, 6),
#  (11, 6),
#  (8, 5),
#  (10, 5),
#  (13, 5),
#  (2, 4),
#  (19, 4),
#  (12, 4),
#  (5, 4),
#  (1, 3),
#  (3, 3),
#  (7, 3),
#  (17, 2),
#  (20, 2)]

# %%
from collections import Counter
f=open('CHULAMOOC_all_messages.txt',encoding='utf-8')
text=f.read()
tokens=text.split()
#print(tokens)
counts=Counter(tokens)
print(counts.most_common())
f.close()
# Out:
# [('ที่', 153), ('ได้', 129), (':', 125), ('ท่าน', 120), ('แล้ว', 116), ("'", 116), ('ลงทะเบียน', 95), ('สามารถ', 92), ('ใน', 90), ('จะ', 83), ('วิชา', 82), ('/', 78), ('ให้', 76), ('ผู้', 75), ('Certificate', 75), ('เปิด', 73), ('แบบ', 73), ('สำรวจ', 69), ('การ', 65), ('Link', 57), ('ขอรับ', 57), ('.', 56), ('มี', 54), ('ผู้เรียน', 51), ('หาก', 48), ('สำหรับ', 43), (')', 43), ('ๆ', 43), ('ทำ', 42), ('และ', 41), ('(', 41), ('คอร์ส', 40), ('หมายเหตุ', 39), ('ไม่', 38), ('of', 38), ('Completion', 38), ('ตอบ', 37), ('หน้า', 36), ('นี้', 36), ('ของ', 35), ('ได้ที่', 34), ('CHULA', 33), ('MOOC', 33), ('2', 32), ('รายชื่อ', 32), ('มา', 31), ('มีสิทธิ์', 30), ('Learner', 30), ('ID', 30), ('ขณะนี้', 29), ('เช่น', 29), ('ขอให้', 28), ('กัน', 28), ('อยู่', 28), ('!', 27), ('เพิ่มเติม', 27), ('1.', 27), ('2.', 27), ('e-mail', 27), ('ค่ะ', 26), ('for', 26), ('อื่น', 25), ('นะคะ', 25), ('..', 25), ('รายวิชา', 25), ('เข้าสู่', 24), ('ไว้', 23), ('กับ', 23), ('ปุ่ม', 23), ('ดังกล่าว', 22), ('เต็ม', 
# ...

# %%
#ชื่อหนังสือและราคาหนังสือ
b1=('Python for Data Science',178)
b2=('Introduction to Python',160)
b3=('วิทยาการคำนวณ',35)
b4=('ภาษาโปรแกรม',200)

books=[b1,b2,b3,b4]
print(books)
print(sorted(books))
print(books)
#sort by price
#p = price
#b = book
new_books=[([p,b]) for (b,p) in books]
print(new_books)
print(sorted(new_books,reverse=True))
price=[p for (p,b) in new_books]
print(price)
print(sum(price)/len(price))
# Out:
# [('Python for Data Science', 178), ('Introduction to Python', 160), ('วิทยาการคำนวณ', 35), ('ภาษาโปรแกรม', 200)]
# [('Introduction to Python', 160), ('Python for Data Science', 178), ('ภาษาโปรแกรม', 200), ('วิทยาการคำนวณ', 35)]
# [('Python for Data Science', 178), ('Introduction to Python', 160), ('วิทยาการคำนวณ', 35), ('ภาษาโปรแกรม', 200)]
# [[178, 'Python for Data Science'], [160, 'Introduction to Python'], [35, 'วิทยาการคำนวณ'], [200, 'ภาษาโปรแกรม']]
# [[200, 'ภาษาโปรแกรม'], [178, 'Python for Data Science'], [160, 'Introduction to Python'], [35, 'วิทยาการคำนวณ']]
# [178, 160, 35, 200]
# 143.25

# %%
f=open('ข้อมูลการจดทะเบียนนิติบุคคล_พ.ศ._2558_รายชื่อนิติบุคคลจัดตั้งใหม่_เดือนมกราคม_CSV.csv',encoding='cp874')
lines=f.readlines()[4:]
f.close()
data=dict()
for line in lines:
    tokens=line.split(',')
    data[tokens[1]]=tokens[2]

print(data['0105558008309'])
print(data['0105558002009'])
# Out:
# บจ.ไซโก โซลูชั่นส์ (ประเทศไทย) จำกัด
# บจ.โจงลี่ เทลซัน โซล่าร์ (ไทยแลนด์) จำกัด

# %%
data=[1,2,7,5,6,10,6,5,8,7,10,7,7]
c=dict()
for item in data:
    if item in c:
        c[item] = c[item] + 1
    else:
        c[item] = 1
print(c[7])
# Out:
# 4

# %%
f=open('ข้อมูลการจดทะเบียนนิติบุคคล_พ.ศ._2558_รายชื่อนิติบุคคลจัดตั้งใหม่_เดือนมกราคม_CSV.csv',encoding='cp874')
lines=f.readlines()[4:]
f.close()
data=list()
for line in lines:
    tokens=line.split(',')
    data.append({'id':tokens[1],'registered name':tokens[2],'registered date':tokens[3]})
    
print(data[10]['registered name'],data[10]['registered date'])
# Out:
# บจ.เทคโทรนิค อินดัสตรี้ส์ (ประเทศไทย) จำกัด 12/1/2558

# %%
f=open('CHULAMOOC_all_messages.txt',encoding='utf-8')
text=f.read()
f.close()
tokens=text.split()
#print(tokens)
print(set(tokens))
# Out:
# {'สำหรับ', 'เลือก', 'การตลาด', 'Page', 'lessons', 'do', 'ใช้ได้', '🗞️👨\u200d🎓', 'Business', '🙏', 'จุฬา', 'ที่จะ', 'Now', 'colors', 'asking', 'ผลงาน', 'คลิก', 'for', 'เพจ', 'กำลัง', 'ทักษะ', 'ร้านค้า', 'เกณฑ์', 'https://mooc.chula.ac.th/courses/arabicfordailylife', 'เมษายน', 'บรรยากาศ', '!!!!', 'หลากหลาย', '+', 'ใหม่', 'อันดับ', 'เท่านั้น', 'weather', 'มุมมอง', 'course', 'วิธีการ', 'Open', 'ขาย', '📢', 'time', 'พัฒนา', 'รายละเอียด', 'รอ', 'Hotel', 'สอบถาม', 'mooc', 'ออ', 'Critical', 'ใคร', 'หลักการ', 'ที่', 'เทศกาล', 'ไม่ได้', '●', 'Microsoft', 'ท่าน', 'งบการเงิน', 'เถอะ', 'appointment', 'เรื่อง', 'สบาย', 'เหมือนกัน', 'แบบสอบถาม', 'รุ่น', 'ไหม', 'วจะ', 'สงกรานต์', 'ChulaMooc', 'staff', 'What', 'สำรวจ', 'an', 'แค่', '📌', 'ที่อยู่', '12', 'นำเสนอ', 'อีกครั้ง', 'FB', 'จบ', 'วิชาการ', 'เม.ย.', '20', 'เยอะ', 'Info', 'รู้จัก', 'ทยอย', 'เสริมสร้าง', 'ผู้เชี่ยวชาญ', 'เรียนรู้', 'ต้อง', 'จ๊าาาาา', 'และ', 'ใช่', 'เพราะ', 'courses', ':', 'Motion', 'โดยเร็ว', 'เช่น', 'ไม่ทราบ', 'เป็น', 'ทำความรู้จ
# ...

# %%
f1=open('CHULAMOOC_all_messages.txt',encoding='utf-8')
f2=open('ChulaEngineering_all_messages.txt',encoding='utf-8')
text=f1.read()
tokens1=set(text.split())
text=f2.read()
tokens2=set(text.split())
f1.close()
f2.close()

print(tokens1.intersection(tokens2))
# Out:
# {'สำหรับ', 'เลือก', 'การตลาด', 'ใช้ได้', 'Business', 'จุฬา', 'ที่จะ', 'ผลงาน', 'คลิก', 'for', 'กำลัง', 'ทักษะ', 'เมษายน', 'บรรยากาศ', '+', 'ใหม่', 'อันดับ', 'เท่านั้น', 'มุมมอง', 'course', 'Open', 'ขาย', 'พัฒนา', 'รายละเอียด', 'สอบถาม', 'ออ', 'ใคร', 'ที่', 'เทศกาล', 'ท่าน', 'เรื่อง', 'แบบสอบถาม', 'รุ่น', 'สงกรานต์', 'สำรวจ', 'an', 'ที่อยู่', '12', 'นำเสนอ', 'วิชาการ', 'เม.ย.', '20', 'Info', 'รู้จัก', 'ผู้เชี่ยวชาญ', 'เรียนรู้', 'ต้อง', 'และ', 'เพราะ', 'courses', ':', 'เช่น', 'เป็น', 'รบกวน', '3', '(', '"', 'How', 'ขอบคุณ', '5', 'แรก', 'วัน', 'ได้รับ', 'พุธ', 'ตัว', '...', 'ถึง', 'อย่า', 'กับ', 'Data', 'ขอ', 'เพื่อ', 'ความคิด', 'ทั่วไป', 'in', 'II', 'เรา', 'สื่อสาร', 'เรียบร้อย', 'ธันวาคม', 'ac', 'th', 'แจ้ง', 'วันที่', 'ใน', 'ทุกท่าน', 'อย่าง', '22', 'หมวด', 'รอบ', ')', 'จาก', '60', 'ด้วย', 'ของ', 'โลก', '15', 'ทำ', 'ทีมงาน', 'ภาษา', 'Certificate', 'เวลา', 'ครบรอบ', '28', 'จุฬาฯ', 'เนื่องจาก', 'เอง', 'เปิด', 'The', 'to', 'เว็บไซต์', 'health', '14.30', 'อย่างดี', 'รับรอง', 'ทราบ', 'นำ
# ...
